# %% [markdown]
# # Orchestration Logic
#
# #### This notebook programmatically runs all Silver transformation notebooks in sequence.
# #### It becomes the single entry point for the Silver layer in Databricks Jobs.

# %%
notebooks = [
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/silver/crm/silver_crm_cust_info",
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/silver/crm/silver_crm_prd_info",
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/silver/crm/silver_crm_sales_details",
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/silver/erp/silver_erp_cust_az12",
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/silver/erp/silver_erp_loc_a101",
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/silver/erp/silver_erp_px_cat_g1v2"
]
