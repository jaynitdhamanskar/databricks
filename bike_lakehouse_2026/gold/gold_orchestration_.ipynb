# %% [markdown]
# # Orchestration Logic
#
# #### This notebook programmatically runs all Gold notebooks in sequence.
# #### It becomes the single entry point for the Gold layer in Databricks Job

# %%
notebooks = [
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/gold/gold_dim_customers",
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/gold/gold_dim_products",
    "/Users/jaynitdhamanskar@gmail.com/databricks/bike_lakehouse_2026/gold/gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
